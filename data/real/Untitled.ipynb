# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_drug = pd.read_csv("drug_targets.csv")
df_gene = pd.read_csv("gene_disease.csv")

# %%
plt.hist(df_drug['score'], bins=30);
plt.yscale('log')

# %%
plt.hist(np.log10(df_gene['score']), bins=30);
#plt.xscale('log')
plt.yscale('log')
